# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
# White, dark, whitegrid, darkgrid

# %%
ping = sns.load_dataset('penguins')
ping
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
ping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
ping.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
ping.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
ping.columns = ['especies', 'ilha', 'comprimento_bico', 'largura_bico', 'comprimento_asa', 'massa_corporal_g', 'sex']

# %%
ping
# Out:
#     especies       ilha  comprimento_bico  largura_bico  comprimento_asa  \
# 0     Adelie  Torgersen              39.1          18.7            181.0
# 1     Adelie  Torgersen              39.5          17.4            186.0
# 2     Adelie  Torgersen              40.3          18.0            195.0
# 3     Adelie  Torgersen               NaN           NaN              NaN
# 4     Adelie  Torgersen              36.7          19.3            193.0
# ..       ...        ...               ...           ...              ...
# 339   Gentoo     Biscoe               NaN           NaN              NaN
# 340   Gentoo     Biscoe              46.8          14.3            215.0
# 341   Gentoo     Biscoe              50.4          15.7            222.0
# 342   Gentoo     Biscoe              45.2          14.8            212.0
# 343   Gentoo     Biscoe              49.9          16.1            213.0
#
#      massa_corporal_g     sex
# 0              3750.0    Male
# ...

# %%
sns.displot(ping['comprimento_bico'], bins = 30, kde = True).set(title= 'DISTPLOT')

# %%
sns.histplot(ping['comprimento_bico'], bins = 30, kde = True).set(title= 'HISTPLOT')
# Out:
# [Text(0.5, 1.0, 'HISTPLOT')]

# %%
sns.jointplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', hue = 'sex')

# %%
sns.jointplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', hue = 'especies')

# %%
sns.jointplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', kind = 'kde' )

# %%
sns.jointplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', kind = 'reg', marker = '^' )

# %%
sns.jointplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', kind = 'hist', hue = 'especies', bins = 30 )

# %%
sns.jointplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', kind = 'hex' )

# %%
ping.head(2)
# Out:
#   especies       ilha  comprimento_bico  largura_bico  comprimento_asa  \
# 0   Adelie  Torgersen              39.1          18.7            181.0
# 1   Adelie  Torgersen              39.5          17.4            186.0
#
#    massa_corporal_g     sex
# 0            3750.0    Male
# 1            3800.0  Female

# %%
sns.lmplot(data = ping, x = 'massa_corporal_g', y = 'comprimento_bico', hue = 'sex')

# %%
sns.lmplot(data = ping, x = 'massa_corporal_g', y = 'comprimento_bico', hue = 'especies')

# %%
sns.pairplot(ping)

# %%
sns.pairplot(ping, hue= 'especies')

# %%
sns.barplot(data = ping, x = 'especies', y = 'comprimento_bico').set(title = 'BARPLOT')
plt.xlabel('Especies', fontsize = 18)
# Out:
# Text(0.5, 0, 'Especies')

# %%
sns.countplot(data = ping, x = 'especies')
# Out:
# <Axes: xlabel='especies', ylabel='count'>

# %%
ping['especies'].value_counts()
# Out:
# especies
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.boxenplot(data= ping, x = 'especies', y='massa_corporal_g', hue = 'sex')
# Out:
# <Axes: xlabel='especies', ylabel='massa_corporal_g'>

# %%
sns.violinplot(data = ping, x = 'especies', y = 'massa_corporal_g', hue='sex', split= True)
# Out:
# <Axes: xlabel='especies', ylabel='massa_corporal_g'>

# %%
p = sns.FacetGrid(ping, col= 'ilha', row = 'especies')
p.map(sns.histplot, 'massa_corporal_g')

# %%
p = sns.FacetGrid(ping, col= 'especies', row = 'sex')
p.map(sns.histplot, 'largura_bico')

# %%
sns.regplot(data=ping, x = 'comprimento_bico', y = 'largura_bico')
# Out:
# <Axes: xlabel='comprimento_bico', ylabel='largura_bico'>

# %%
sns.relplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', hue = 'sex', size = 'massa_corporal_g', sizes = (1, 100), alpha = 0.7)

# %%
sns.scatterplot(data = ping, x = 'comprimento_bico', y = 'largura_bico', hue = 'sex')
# Out:
# <Axes: xlabel='comprimento_bico', ylabel='largura_bico'>
